# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

from helpers import postprocess, extend_summary_from_logs

# %%
# sns.set_style('white')
# sns.set_context("paper", rc={
#     "figure.dpi": 600,
#     "savefig.dpi": 600,
# })

sns.set_context('paper', rc={'figure.dpi': 600})
sns.set_style("ticks")
# sns.set_style("whitegrid")


# set text length for each column of dataframe higher
pd.set_option('display.max_colwidth', 1000)

# %%
root = Path('../hpc_scripts/.duct/').resolve()
assert root.exists(), f"Path {root} does not exist"
files = [root / 'logs_aggregation_009', root / 'logs_aggregation_010', root / 'logs_aggregation_011']

summaries = []
for f in files:
    try:
        extend_summary_from_logs(f)
    except Exception as e:
        print(f"Error processing {f}: {e}")
summaries = [f / 'summary.csv' for f in files if (f / 'summary.csv').exists()]
df = pd.concat((pd.read_csv(s) for s in summaries), ignore_index=True)
df
# Out:
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_5000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_5000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_500_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_20000_2info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_20000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_1000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_2000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_2000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_5000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_10000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_500_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_20000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_1000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_500_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_20000_4info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_20000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_1000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_500_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_5000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_2000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_500_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_20000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_500_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_5000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_1000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_2000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_20000_4info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_20000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_10000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_1000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_2000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_10000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_500_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_2000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_5000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_10000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_500_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_5000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_1000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_10000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_2000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_500_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_2000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_20000_8info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_20000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_2000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_10000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_5000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_20000_1info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_20000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_10000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_10000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_2000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_10000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_10000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_5000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_20000_4info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_20000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_10000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_500_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_1000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_2000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_1000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_1000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_1000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_1000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_500_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_500_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_1000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_500_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_20000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_10000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_5000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_5000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_20000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_2000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_500_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_2000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_20000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_20000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_2000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_500_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_20000_8info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_20000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_10000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_1000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_1000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_20000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_1000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_2000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_5000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_2000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_2000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_20000_2info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_20000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_10000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_20000_8info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_20000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_5000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_1000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_1000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_5000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_10000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_2000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_500_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_2000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_20000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_500_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_1000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_5000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_500_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_2000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_10000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_5000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_1000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_5000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_5000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_10000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/harpy_10000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_20000_2info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_20000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_1000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_500_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_20000_1info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/sopa_20000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_500_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_5000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_10000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_20000_1info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/xr_spatial_20000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/squidpy_10000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_009/spatialdata_5000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_5000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_5000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_500_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_20000_2info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_20000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_1000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_2000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_2000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_5000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_10000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_500_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_20000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_1000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_500_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_20000_4info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_20000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_1000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_500_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_5000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_2000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_500_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_20000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_500_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_5000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_1000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_2000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_20000_4info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_20000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_10000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_1000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_2000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_10000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_500_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_2000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_5000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_10000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_500_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_5000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_1000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_10000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_2000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_500_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_2000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_20000_8info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_20000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_2000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_10000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_5000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_20000_1info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_20000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_10000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_10000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_2000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_10000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_10000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_5000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_20000_4info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_20000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_10000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_500_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_1000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_2000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_1000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_1000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_1000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_1000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_500_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_500_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_1000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_500_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_20000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_10000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_5000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_5000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_20000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_2000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_500_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_2000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_20000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_20000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_2000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_500_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_20000_8info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_20000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_10000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_1000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_1000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_20000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_1000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_2000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_5000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_2000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_2000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_20000_2info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_20000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_10000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_20000_8info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_20000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_5000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_1000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_1000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_5000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_10000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_2000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_500_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_2000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_20000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_500_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_1000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_5000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_500_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_2000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_10000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_5000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_1000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_5000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_5000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_10000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/harpy_10000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_20000_2info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_20000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_1000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_500_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_20000_1info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/sopa_20000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_500_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_5000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_10000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_20000_1info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/xr_spatial_20000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/squidpy_10000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_010/spatialdata_5000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_5000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_5000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_500_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_20000_2info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_20000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_1000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_2000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_2000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_5000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_10000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_500_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_20000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_1000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_500_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_20000_4info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_20000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_1000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_500_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_5000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_2000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_500_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_20000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_500_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_5000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_1000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_2000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_20000_4info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_20000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_10000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_1000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_2000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_10000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_500_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_2000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_5000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_10000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_500_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_5000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_1000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_10000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_2000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_500_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_2000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_20000_8info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_20000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_2000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_10000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_5000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_20000_1info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_20000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_10000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_10000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_2000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_10000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_10000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_5000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_20000_4info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_20000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_10000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_500_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_1000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_2000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_1000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_1000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_1000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_1000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_500_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_500_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_1000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_500_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_20000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_10000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_5000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_5000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_20000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_2000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_500_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_2000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_20000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_20000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_2000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_500_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_20000_8info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_20000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_10000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_1000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_1000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_20000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_1000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_2000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_5000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_2000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_2000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_20000_2info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_20000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_10000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_20000_8info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_20000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_5000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_1000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_1000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_5000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_10000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_2000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_500_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_2000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_20000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_500_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_1000_8info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_5000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_500_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_2000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_10000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_5000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_1000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_5000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_5000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_10000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/harpy_10000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_20000_2info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_20000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_1000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_500_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_20000_1info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/sopa_20000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_500_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_5000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_10000_2info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_20000_1info.json
# Skipping /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/xr_spatial_20000_1info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/squidpy_10000_4info.json
# Processing /kyukon/data/gent/vo/000/gvo00070/vsc43257/harpy_figures/hpc_scripts/.duct/logs_aggregation_011/spatialdata_5000_2info.json
#      exit_code  \
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 319          0
# 320          0
# 321          0
# 322          0
# 323          0
#
#                                                                                                                                                                                                                                                     command  \
# 0      python ../benchmark_aggregation.py --dataset /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_009_xr_spatial_5000_1.zarr --img_layer image_tiled --labels_layer labels_cells_harpy --threads 1 --workers 1 --method xr_spatial
# 1                  python ../benchmark_aggregation.py --dataset /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_009_sopa_5000_8.zarr --img_layer image_tiled --labels_layer labels_cells_harpy --threads 8 --workers 1 --method sopa
# 2             python ../benchmark_aggregation.py --dataset /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_009_squidpy_500_1.zarr --img_layer image_tiled --labels_layer labels_cells_harpy --threads 1 --workers 1 --method squidpy
# 3    python ../benchmark_aggregation.py --dataset /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_009_spatialdata_1000_2.zarr --img_layer image_tiled --labels_layer labels_cells_harpy --threads 2 --workers 1 --method spatialdata
# 4      python ../benchmark_aggregation.py --dataset /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_009_xr_spatial_2000_8.zarr --img_layer image_tiled --labels_layer labels_cells_harpy --threads 8 --workers 1 --method xr_spatial
# ..                                                                                                                                                                                                                                                      ...
# 319           python ../benchmark_aggregation.py --dataset /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_011_squidpy_500_4.zarr --img_layer image_tiled --labels_layer labels_cells_harpy --threads 4 --workers 1 --method squidpy
# 320          python ../benchmark_aggregation.py --dataset /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_011_squidpy_5000_1.zarr --img_layer image_tiled --labels_layer labels_cells_harpy --threads 1 --workers 1 --method squidpy
# 321         python ../benchmark_aggregation.py --dataset /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_011_squidpy_10000_2.zarr --img_layer image_tiled --labels_layer labels_cells_harpy --threads 2 --workers 1 --method squidpy
# 322         python ../benchmark_aggregation.py --dataset /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_011_squidpy_10000_4.zarr --img_layer image_tiled --labels_layer labels_cells_harpy --threads 4 --workers 1 --method squidpy
# 323  python ../benchmark_aggregation.py --dataset /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_011_spatialdata_5000_2.zarr --img_layer image_tiled --labels_layer labels_cells_harpy --threads 2 --workers 1 --method spatialdata
#
#                                        logs_prefix  wall_clock_time  \
# 0     .duct/logs_aggregation_009/xr_spatial_5000_1       495.537449
# 1           .duct/logs_aggregation_009/sopa_5000_8       125.702978
# 2         .duct/logs_aggregation_009/squidpy_500_1        77.793652
# 3    .duct/logs_aggregation_009/spatialdata_1000_2       104.462739
# 4     .duct/logs_aggregation_009/xr_spatial_2000_8       112.720777
# ..                                             ...              ...
# 319       .duct/logs_aggregation_011/squidpy_500_4       175.660756
# 320      .duct/logs_aggregation_011/squidpy_5000_1       155.896883
# 321     .duct/logs_aggregation_011/squidpy_10000_2       363.688265
# 322     .duct/logs_aggregation_011/squidpy_10000_4       282.904659
# 323  .duct/logs_aggregation_011/spatialdata_5000_2       468.583923
#
#         peak_rss   average_rss     peak_vsz   average_vsz  peak_pmem  \
# 0     1418194944  1.176735e+09   4142682112  3.694785e+09        0.4
# 1     2677473280  7.503888e+08   6119550976  2.304951e+09        0.9
# 2     1266012160  3.114594e+08   4205268992  1.071962e+09        0.4
# 3     1042567168  4.765714e+08   3993432064  1.829783e+09        0.3
# 4     1231929344  5.962676e+08   4707803136  2.323136e+09        0.3
# ..           ...           ...          ...           ...        ...
# 319   3467763712  1.309619e+09  10012565504  4.386051e+09        0.8
# 320  13994524672  6.518024e+09  16928722944  8.267953e+09        5.1
# 321  68329336832  4.492957e+10  75267076096  5.236586e+10       25.1
# 322  78011785216  4.613221e+10  94937899008  5.783692e+10       28.6
# 323   1368002560  1.081909e+09   4260839424  3.608535e+09        0.4
#
#      average_pmem  ...  \
# 0        0.360752  ...
# 1        0.217600  ...
# 2        0.072727  ...
# 3        0.098551  ...
# 4        0.133482  ...
# ..            ...  ...
# 319      0.333046  ...
# 320      2.322295  ...
# 321     16.455226  ...
# 322     16.813718  ...
# 323      0.348108  ...
#
#                                                                                                 dataset  \
# 0     /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_009_xr_spatial_5000_1.zarr
# 1           /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_009_sopa_5000_8.zarr
# 2         /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_009_squidpy_500_1.zarr
# 3    /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_009_spatialdata_1000_2.zarr
# 4     /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_009_xr_spatial_2000_8.zarr
# ..                                                                                                  ...
# 319       /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_011_squidpy_500_4.zarr
# 320      /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_011_squidpy_5000_1.zarr
# 321     /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_011_squidpy_10000_2.zarr
# 322     /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_011_squidpy_10000_4.zarr
# 323  /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_011_spatialdata_5000_2.zarr
#
#        img_layer        labels_layer  threads  workers       method c_dim  \
# 0    image_tiled  labels_cells_harpy        1        1   xr_spatial    20
# 1    image_tiled  labels_cells_harpy        8        1         sopa    20
# 2    image_tiled  labels_cells_harpy        1        1      squidpy    20
# 3    image_tiled  labels_cells_harpy        2        1  spatialdata    20
# 4    image_tiled  labels_cells_harpy        8        1   xr_spatial    20
# ..           ...                 ...      ...      ...          ...   ...
# 319  image_tiled  labels_cells_harpy        4        1      squidpy    20
# 320  image_tiled  labels_cells_harpy        1        1      squidpy    20
# 321  image_tiled  labels_cells_harpy        2        1      squidpy    20
# 322  image_tiled  labels_cells_harpy        4        1      squidpy    20
# 323  image_tiled  labels_cells_harpy        2        1  spatialdata    20
#
#      x_dim  y_dim      pixels
# 0     5000   5000   500000000
# 1     5000   5000   500000000
# 2      500    500     5000000
# 3     1000   1000    20000000
# 4     2000   2000    80000000
# ..     ...    ...         ...
# 319    500    500     5000000
# 320   5000   5000   500000000
# 321  10000  10000  2000000000
# 322  10000  10000  2000000000
# 323   5000   5000   500000000
#
# [324 rows x 26 columns]

# %%
# bad exit codes
df[df['exit_code'] != 0][['workers', 'method', 'x_dim', 'pixels']]
# Out:
#      workers   method  x_dim      pixels
# 17         1  squidpy  20000  8000000000
# 58         1  squidpy  20000  8000000000
# 88         1  squidpy  20000  8000000000
# 125        1  squidpy  20000  8000000000
# 166        1  squidpy  20000  8000000000
# 196        1  squidpy  20000  8000000000
# 233        1  squidpy  20000  8000000000
# 274        1  squidpy  20000  8000000000
# 304        1  squidpy  20000  8000000000

# %%
# make sure to incorporate the 10% subsetting

# filter out bad exit codes
df = df[df['exit_code'] == 0]

# %%
# filter

# make workers same as threads
df['workers'] = df['threads']

# df['method'] = 'flowsom'
df
# Out:
# /tmp/ipykernel_1578810/2513031601.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['workers'] = df['threads']
#      exit_code  \
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 319          0
# 320          0
# 321          0
# 322          0
# 323          0
#
#                                                                                                                                                                                                                                                     command  \
# 0      python ../benchmark_aggregation.py --dataset /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_009_xr_spatial_5000_1.zarr --img_layer image_tiled --labels_layer labels_cells_harpy --threads 1 --workers 1 --method xr_spatial
# 1                  python ../benchmark_aggregation.py --dataset /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_009_sopa_5000_8.zarr --img_layer image_tiled --labels_layer labels_cells_harpy --threads 8 --workers 1 --method sopa
# 2             python ../benchmark_aggregation.py --dataset /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_009_squidpy_500_1.zarr --img_layer image_tiled --labels_layer labels_cells_harpy --threads 1 --workers 1 --method squidpy
# 3    python ../benchmark_aggregation.py --dataset /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_009_spatialdata_1000_2.zarr --img_layer image_tiled --labels_layer labels_cells_harpy --threads 2 --workers 1 --method spatialdata
# 4      python ../benchmark_aggregation.py --dataset /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_009_xr_spatial_2000_8.zarr --img_layer image_tiled --labels_layer labels_cells_harpy --threads 8 --workers 1 --method xr_spatial
# ..                                                                                                                                                                                                                                                      ...
# 319           python ../benchmark_aggregation.py --dataset /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_011_squidpy_500_4.zarr --img_layer image_tiled --labels_layer labels_cells_harpy --threads 4 --workers 1 --method squidpy
# 320          python ../benchmark_aggregation.py --dataset /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_011_squidpy_5000_1.zarr --img_layer image_tiled --labels_layer labels_cells_harpy --threads 1 --workers 1 --method squidpy
# 321         python ../benchmark_aggregation.py --dataset /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_011_squidpy_10000_2.zarr --img_layer image_tiled --labels_layer labels_cells_harpy --threads 2 --workers 1 --method squidpy
# 322         python ../benchmark_aggregation.py --dataset /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_011_squidpy_10000_4.zarr --img_layer image_tiled --labels_layer labels_cells_harpy --threads 4 --workers 1 --method squidpy
# 323  python ../benchmark_aggregation.py --dataset /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_011_spatialdata_5000_2.zarr --img_layer image_tiled --labels_layer labels_cells_harpy --threads 2 --workers 1 --method spatialdata
#
#                                        logs_prefix  wall_clock_time  \
# 0     .duct/logs_aggregation_009/xr_spatial_5000_1       495.537449
# 1           .duct/logs_aggregation_009/sopa_5000_8       125.702978
# 2         .duct/logs_aggregation_009/squidpy_500_1        77.793652
# 3    .duct/logs_aggregation_009/spatialdata_1000_2       104.462739
# 4     .duct/logs_aggregation_009/xr_spatial_2000_8       112.720777
# ..                                             ...              ...
# 319       .duct/logs_aggregation_011/squidpy_500_4       175.660756
# 320      .duct/logs_aggregation_011/squidpy_5000_1       155.896883
# 321     .duct/logs_aggregation_011/squidpy_10000_2       363.688265
# 322     .duct/logs_aggregation_011/squidpy_10000_4       282.904659
# 323  .duct/logs_aggregation_011/spatialdata_5000_2       468.583923
#
#         peak_rss   average_rss     peak_vsz   average_vsz  peak_pmem  \
# 0     1418194944  1.176735e+09   4142682112  3.694785e+09        0.4
# 1     2677473280  7.503888e+08   6119550976  2.304951e+09        0.9
# 2     1266012160  3.114594e+08   4205268992  1.071962e+09        0.4
# 3     1042567168  4.765714e+08   3993432064  1.829783e+09        0.3
# 4     1231929344  5.962676e+08   4707803136  2.323136e+09        0.3
# ..           ...           ...          ...           ...        ...
# 319   3467763712  1.309619e+09  10012565504  4.386051e+09        0.8
# 320  13994524672  6.518024e+09  16928722944  8.267953e+09        5.1
# 321  68329336832  4.492957e+10  75267076096  5.236586e+10       25.1
# 322  78011785216  4.613221e+10  94937899008  5.783692e+10       28.6
# 323   1368002560  1.081909e+09   4260839424  3.608535e+09        0.4
#
#      average_pmem  ...  \
# 0        0.360752  ...
# 1        0.217600  ...
# 2        0.072727  ...
# 3        0.098551  ...
# 4        0.133482  ...
# ..            ...  ...
# 319      0.333046  ...
# 320      2.322295  ...
# 321     16.455226  ...
# 322     16.813718  ...
# 323      0.348108  ...
#
#                                                                                                 dataset  \
# 0     /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_009_xr_spatial_5000_1.zarr
# 1           /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_009_sopa_5000_8.zarr
# 2         /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_009_squidpy_500_1.zarr
# 3    /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_009_spatialdata_1000_2.zarr
# 4     /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_009_xr_spatial_2000_8.zarr
# ..                                                                                                  ...
# 319       /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_011_squidpy_500_4.zarr
# 320      /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_011_squidpy_5000_1.zarr
# 321     /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_011_squidpy_10000_2.zarr
# 322     /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_011_squidpy_10000_4.zarr
# 323  /data/gent/vo/000/gvo00070/vsc43257/VIB/DATA/benchmark_harpy/sdata_agg_011_spatialdata_5000_2.zarr
#
#        img_layer        labels_layer  threads  workers       method c_dim  \
# 0    image_tiled  labels_cells_harpy        1        1   xr_spatial    20
# 1    image_tiled  labels_cells_harpy        8        8         sopa    20
# 2    image_tiled  labels_cells_harpy        1        1      squidpy    20
# 3    image_tiled  labels_cells_harpy        2        2  spatialdata    20
# 4    image_tiled  labels_cells_harpy        8        8   xr_spatial    20
# ..           ...                 ...      ...      ...          ...   ...
# 319  image_tiled  labels_cells_harpy        4        4      squidpy    20
# 320  image_tiled  labels_cells_harpy        1        1      squidpy    20
# 321  image_tiled  labels_cells_harpy        2        2      squidpy    20
# 322  image_tiled  labels_cells_harpy        4        4      squidpy    20
# 323  image_tiled  labels_cells_harpy        2        2  spatialdata    20
#
#      x_dim  y_dim      pixels
# 0     5000   5000   500000000
# 1     5000   5000   500000000
# 2      500    500     5000000
# 3     1000   1000    20000000
# 4     2000   2000    80000000
# ..     ...    ...         ...
# 319    500    500     5000000
# 320   5000   5000   500000000
# 321  10000  10000  2000000000
# 322  10000  10000  2000000000
# 323   5000   5000   500000000
#
# [315 rows x 26 columns]

# %% [markdown]
# ## Wall clock time

# %%
# sns.lineplot(data=df, x="config_duration", y="wall_clock_time", err_style="bars", errorbar=("se", 2), marker='o')

# %%
def extrapolated_y(axs):
    from copy import deepcopy
    # add grey extrapolation lines for missing points
    axs = deepcopy(axs)
    unique_xs = {x for line in axs.lines for x in line.get_xdata() }
    for line in axs.lines:
        xs, ys = line.get_data()
        missing_xs = unique_xs - set(xs)
        # plot extrapolation lines between last xs and missing xs
        if len(xs) >= 2:
            last_x = xs[-1]
            for missing_x in missing_xs:
                # calculate extrapolated y by linear extrapolation from last two points
                last_y = ys[-1]
                second_last_x = xs[-2]
                second_last_y = ys[-2]
                slope = (last_y - second_last_y) / (last_x - second_last_x)
                extrapolated_y = last_y + slope * (missing_x - last_x)
                # plot extrapolation line with same style as original line, make the shade lighter
                axs.plot([last_x, missing_x], [last_y, extrapolated_y], color=line.get_color(), linestyle=line.get_linestyle(), alpha=0.3)
    return axs

# %%
# df = df[df['threads'].isin([1, 4, 8])]

# if method != 'flowsom+batch' and threads != 1, filter out
hue_order = ['harpy', 'sopa', 'squidpy', 'xr_spatial', 'spatialdata']
df['method'] = pd.Categorical(df['method'], hue_order)
df_subset = df #[~((df['method'] != 'flowsom_batch') & (df['workers'] != 1))]


# set colors to orange, blue, purple and green
cmap = sns.color_palette("Dark2")
# change order in cmap, switch first two colors
cmap[0], cmap[1] = cmap[1], cmap[0]
sns.set_palette(cmap)

dash_styles = {
    1: (1, 0),
    2: (4, 1),
    4: (2, 1),
    8: (1, 1),
}

axs = sns.lineplot(data=df_subset, x="pixels", y="wall_clock_time", hue="method", marker='o', style='workers', dashes=dash_styles)
plt.xlabel('Dataset size (pixels)')
plt.ylabel('Wall clock time (s)')

# make logarithmic
plt.yscale('log', base=10)
plt.xscale('log', base=10)
# # add more ticks to y
# plt.yticks([100, 1000, 10_000], ['100', '1000', '10000'])
# import matplotlib as mpl
# axs.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
# plt.grid(True, which="both")
postprocess(axs)

# %%
# plot number of pixels and wall clock time on the same plot for each method and each thread count
axs = sns.lineplot(data=df, x="pixels", y="wall_clock_time", hue="method", marker='o', style='workers', dashes=dash_styles)
plt.xlabel('Dataset size (pixels)')
plt.ylabel('Wall clock time (s)')
plt.xscale('log', base=10)
postprocess(axs)

# %%
# same plot as above but with a relplot of method as multiple facets
g = sns.relplot(data=df, x="pixels", y="wall_clock_time", hue="method", col="workers", kind="line", dashes=dash_styles)
# g.set_axis_labels("Dataset size (pixels)", "Wall clock time (s)")
g.set_axis_labels("Dataset size (pixels)", "Wall clock time (s)")
# g.set_titles(col_template="{col_name} workers")
g.set_titles(col_template="{col_name} workers")
g.set(xscale="log")
g.set(yscale="log")
postprocess(g.legend)

# %%
df['pixels'].unique()
# Out:
# array([ 500000000,    5000000,   20000000,   80000000, 2000000000,
#        8000000000])

# %%
# plot on x axis the amount of workers and on y axis the number of pixels processed per second

df_max = df[df['pixels'] == 500_000_000].copy()

# calculate pixels per second
df_max['pixels_per_second'] = df_max['pixels'] / df_max['wall_clock_time']

# plot speedup
axs = sns.lineplot(data=df_max, x="workers", y="pixels_per_second", hue="method", marker='o')
plt.xlabel('Number of workers')
plt.ylabel('pixels / second')

postprocess(axs)

# %%
df = df[df['threads'].isin([1, 2, 4, 8])]

# hue_order = ['flowsom', 'flowsom_batch', 'pyflowsom']
# hue_order = ['flowsom', 'flowsom_batch', 'pyflowsom']
# set colors to orange, blue, purple and green
cmap = sns.color_palette("Dark2")
# change order in cmap, switch first two colors
cmap[0], cmap[1] = cmap[1], cmap[0]
sns.set_palette(cmap)

df['method'] = pd.Categorical(df['method'], hue_order)
dash_styles = {
    1: (1, 0),
    2: (4, 1),
    4: (2, 1),
    8: (1, 1),
}

axs = sns.lineplot(data=df, x="pixels", y="wall_clock_time", hue="method", marker='o', style='workers', dashes=dash_styles)
plt.xlabel('Dataset size (pixels)')
plt.ylabel('Wall clock time (s)')

# make logarithmic
plt.yscale('log', base=10)
plt.xscale('log', base=10)
# # add more ticks to y
# plt.yticks([100, 1000, 10_000], ['100', '1000', '10000'])
# import matplotlib as mpl
# axs.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
# plt.grid(True, which="both")
postprocess(axs)

# %%
df_gb = df.copy()
df_gb['peak_rss'] /= 1_000_000_000
# remove 2 and 4 workers
df_gb = df_gb[df_gb['workers'] != 2]
df_gb = df_gb[df_gb['workers'] != 4]

# %%
axs = sns.lineplot(data=df_gb, x="pixels", y="peak_rss", hue="method", marker='o', style='workers', dashes=dash_styles)
# extrapolated_y(axs)
plt.xlabel('Dataset size (pixels)')
plt.ylabel('Peak RSS (GB)')

# make logarithmic
plt.yscale('log', base=10)
plt.xscale('log', base=10)
# add line at 150GB y
# plt.axhline(y=30, color='r', linestyle='--')
# add more ticks to y
# plt.yticks([0, 10, 50, 100])
import matplotlib as mpl
axs.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))

handles, labels = axs.get_legend_handles_labels()
# axs.legend(handles, labels, fontsize=16, title_fontsize=20)
print(labels)
# plt.grid(True, which="both")
postprocess(axs)
# Out:
# ['method', 'harpy', 'sopa', 'squidpy', 'xr_spatial', 'spatialdata', 'workers', '1', '8']

# %%
# make a seaborn relpot with multiple facets, one for each worker count (column). One row is wall clock time and the row below is memory
g = sns.relplot(data=df_gb, x="pixels", y="wall_clock_time", hue="method", col="workers", kind="line", marker='o')
g.set_axis_labels("Dataset size (pixels)", "Wall clock time (s)")
g.set_titles(col_template="{col_name} workers")
g.set(xscale="log")
g.set(yscale="log")
postprocess(g.legend)

# %%
# make a seaborn relpot with multiple facets, one for each worker count (column). One row is wall clock time and the row below is memory
g = sns.relplot(data=df_gb, x="pixels", y="peak_rss", hue="method", col="workers", kind="line", marker='o')
g.set_axis_labels("Dataset size (pixels)", "Peak RSS (GB)")
g.set_titles(col_template="{col_name} workers")
g.set(xscale="log")
g.set(yscale="log")
postprocess(g.legend)
